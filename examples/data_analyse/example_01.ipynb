# %%
import init
# Out:
# init

# %%
from analyse_tool import DataAnalysis
from vnpy.trader.constant import Exchange, Interval
from datetime import datetime
# Out:
# d:\python64_373\lib\site-packages\deap\tools\_hypervolume\pyhv.py:33: ImportWarning: Falling back to the python version of hypervolume module. Expect this to be very slow.
#   "module. Expect this to be very slow.", ImportWarning)

# %%
da = DataAnalysis()

# %%
da.load_history('RB2001', Exchange.SHFE, Interval.MINUTE, datetime(2019, 1, 1), datetime(2019, 10, 1))
# Out:
# 2019-11-05 09:14:29.088290	开始加载历史数据
# 2019-11-05 09:14:32.929674	历史数据加载完成，数据量：59085

# %%
da.base_analysis()
# Out:
# 2019-11-05 09:14:36.215003	第一步:画出行情图，检查数据断点
# 2019-11-05 09:14:38.674249	第二步：随机性检验：非纯随机性
# 2019-11-05 09:14:38.675249	白噪声检验结果:(array([59070.2193881]), array([0.]))
#
# 2019-11-05 09:14:57.652146	第三步：平稳性检验：存在单位根，时间序列不平稳
# 2019-11-05 09:14:57.653146	ADF检验结果：(-2.221597647260938, 0.19850033966042435, 15, 59069, {'1%': -3.4304607109346508, '5%': -2.861588932124979, '10%': -2.566796044922964}, 263268.48110820906)
#
# 2019-11-05 09:14:57.653146	第四步：画出自相关性图，观察自相关特性
# 2019-11-05 09:15:00.395420	第五步：相对波动率分析
# 2019-11-05 09:15:01.620543	样本平均数：2.8274, 中位数: 2.7703
# 2019-11-05 09:15:01.622543	偏度为：0.631，属于分布偏左；峰度为：1.3098，属于分布陡峭
#
# 2019-11-05 09:15:01.622543	第六步：变化率分析
# 2019-11-05 09:15:02.595640	样本平均数：0.0018, 中位数: 0.0
# 2019-11-05 09:15:02.597641	偏度为：234.2893，属于分布偏左；峰度为：56254.5052，属于分布陡峭
#
# 2019-11-05 09:15:02.597641	第七步：计算相关技术指标，返回DataFrame
#                        open    high     low   close   volume  volatility  \
# 2019-01-15 21:00:00  3200.0  3220.0  3199.0  3205.0    228.0         NaN
# ...

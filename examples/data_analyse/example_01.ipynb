# %%
import init
# Out:
# init

# %%
from analyse_tool import DataAnalysis
from vnpy.trader.constant import Exchange, Interval
from datetime import datetime
# Out:
# d:\python64_373\lib\site-packages\deap\tools\_hypervolume\pyhv.py:33: ImportWarning: Falling back to the python version of hypervolume module. Expect this to be very slow.
#   "module. Expect this to be very slow.", ImportWarning)

# %%
da = DataAnalysis()

# %%
da.load_history('JD2001', Exchange.DCE, Interval.MINUTE, datetime(2019, 1, 1), datetime(2019, 10, 1))
# Out:
# 2019-11-28 08:58:28.031090	开始加载历史数据
# 2019-11-28 08:58:30.301090	历史数据加载完成，数据量：36900

# %%
da.plot_close_price()
# Out:
# 2019-11-28 08:58:30.509090	第一步:画出行情图，检查数据断点
# (                       open    high     low   close  volume
#  2019-01-29 09:00:00  3748.0  3767.0  3748.0  3764.0    66.0
#  2019-01-29 09:01:00  3765.0  3789.0  3765.0  3767.0    34.0
#  2019-01-29 09:02:00  3792.0  3792.0  3769.0  3769.0    26.0
#  2019-01-29 09:03:00  3774.0  3774.0  3770.0  3770.0    20.0
#  2019-01-29 09:04:00  3770.0  3771.0  3770.0  3771.0    34.0
#  2019-01-29 09:05:00  3772.0  3772.0  3768.0  3768.0    74.0
#  2019-01-29 09:06:00  3767.0  3773.0  3767.0  3773.0     6.0
#  2019-01-29 09:07:00  3774.0  3774.0  3774.0  3774.0     2.0
#  2019-01-29 09:08:00  3774.0  3774.0  3773.0  3773.0     8.0
#  2019-01-29 09:09:00  3773.0  3773.0  3773.0  3773.0     0.0
#  2019-01-29 09:10:00  3774.0  3774.0  3774.0  3774.0     4.0
#  2019-01-29 09:11:00  3774.0  3774.0  3773.0  3773.0     4.0
#  2019-01-29 09:12:00  3771.0  3771.0  3769.0  3769.0    14.0
#  2019-01-29 09:13:00  3773.0  3773.0  3768.0  3768.0    28.0
# ...

# %%
da8888 = DataAnalysis()
da8888.load_history('JD8888', Exchange.DCE, Interval.MINUTE, datetime(2019, 1, 1), datetime(2019, 10, 1))
da8888.plot_close_price()
# Out:
# 2019-11-28 09:11:45.362090	开始加载历史数据
# 2019-11-28 09:11:47.889090	历史数据加载完成，数据量：41175
# 2019-11-28 09:11:48.111090	第一步:画出行情图，检查数据断点
# (                        open     high      low    close  volume
#  2019-01-02 09:00:00  3541.10  3550.64  3538.99  3547.40  7530.0
#  2019-01-02 09:01:00  3548.58  3548.98  3544.00  3547.45  1668.0
#  2019-01-02 09:02:00  3547.92  3552.30  3547.92  3550.51  1418.0
#  2019-01-02 09:03:00  3549.38  3550.14  3544.61  3545.56  1110.0
#  2019-01-02 09:04:00  3545.48  3547.00  3544.71  3546.24   528.0
#  2019-01-02 09:05:00  3547.37  3549.66  3546.61  3548.90   490.0
#  2019-01-02 09:06:00  3549.66  3551.19  3548.81  3549.57   638.0
#  2019-01-02 09:07:00  3549.36  3550.12  3548.42  3548.42   702.0
#  2019-01-02 09:08:00  3548.69  3550.21  3547.92  3549.45   376.0
#  2019-01-02 09:09:00  3549.37  3550.89  3548.60  3550.89   342.0
#  2019-01-02 09:10:00  3550.15  3550.92  3546.90  3546.90   620.0
# ...

# %%
da8888 = DataAnalysis()
da8888.load_history('RB9999', Exchange.SHFE, Interval.MINUTE, datetime(2019, 1, 1), datetime(2019, 10, 1))
da8888.plot_close_price()
# Out:
# 2019-11-28 09:17:33.002090	开始加载历史数据
# 2019-11-28 09:17:36.763090	历史数据加载完成，数据量：62415
# 2019-11-28 09:17:37.150090	第一步:画出行情图，检查数据断点
# (                       open    high     low   close   volume
#  2019-01-02 09:00:00  3398.0  3405.0  3389.0  3400.0  79572.0
#  2019-01-02 09:01:00  3401.0  3430.0  3401.0  3409.0  88858.0
#  2019-01-02 09:02:00  3410.0  3414.0  3409.0  3413.0  22584.0
#  2019-01-02 09:03:00  3412.0  3413.0  3403.0  3405.0  17688.0
#  2019-01-02 09:04:00  3404.0  3409.0  3404.0  3406.0  15522.0
#  2019-01-02 09:05:00  3405.0  3406.0  3400.0  3402.0  20498.0
#  2019-01-02 09:06:00  3402.0  3403.0  3400.0  3400.0  13328.0
#  2019-01-02 09:07:00  3401.0  3406.0  3400.0  3406.0  11668.0
#  2019-01-02 09:08:00  3406.0  3413.0  3405.0  3413.0  18370.0
#  2019-01-02 09:09:00  3413.0  3415.0  3411.0  3414.0  18170.0
#  2019-01-02 09:10:00  3415.0  3416.0  3411.0  3414.0  14870.0
#  2019-01-02 09:11:00  3415.0  3415.0  3411.0  3413.0  11546.0
# ...
